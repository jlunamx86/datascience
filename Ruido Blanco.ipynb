# %%
import numpy as np

# %%
array = np.random.normal(0.0, 1.0, 1000)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(array) 
plt.show()

# %%
z = np.full([1000], None)

# %%
import math

# %%
const = 1 / math.sqrt(2)

# %%
i = 0
for val in array:
    if i % 2 == 0:
        z[i] = val
    else:
        if i > 0:
            z[i] = const * ( pow(array[i-1],2) - 1)
        else:   
            const * ( pow(array[i],2) - 1)
            
    i = i + 1

# %%
plt.plot(z) 
plt.show()
