# %% [markdown]
# <h1>Hypothesis Testing</h1>
# <h2>T - Student</h2>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st
from scipy.stats import f_oneway
from scipy.stats import ttest_ind

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
names = ['sepal-length','sepal-width','petal-length','petal-width','class']
iris = pd.read_csv(url,names=names)
iris.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# <h3>Standard Error</h3>

# %% [markdown]
# ![SE.PNG](attachment:SE.PNG)

# %%
se_length = iris.std()['sepal-length']/np.sqrt(len(iris))
se_width = iris.std()['sepal-width']/np.sqrt(len(iris))

# %%
se_length
# Out:
# 0.0676113162275986

# %%
se_width
# Out:
# 0.03540282727369267

# %% [markdown]
# <h3>Standard Error Deviation</h3>

# %% [markdown]
# ![SED.PNG](attachment:SED.PNG)

# %%
sed = np.sqrt((se_length**2) + (se_width**2))
sed
# Out:
# 0.07631939636160165

# %% [markdown]
# ![t_student.PNG](attachment:t_student.PNG)

# %%
t_stat = (iris.mean()['sepal-length'] - iris.mean()['sepal-width'])/sed
t_stat
# Out:
# 36.548157693982006

# %%
p = ttest_ind(iris['sepal-length'],iris['sepal-width'])
p
# Out:
# Ttest_indResult(statistic=36.548157693982006, pvalue=3.987838114848222e-112)

# %% [markdown]
# <p> t is much greater than p-value then H0 (distributions are similar) is rejected</p>

# %% [markdown]
# <h2>Pearson</h2>

# %%
iris['sepal-length'].corr(iris['sepal-width'])
# Out:
# -0.10936924995064937

# %%
st.pearsonr(iris['sepal-length'],iris['sepal-width'])
# Out:
# (-0.10936924995064935, 0.1827652152713699)

# %% [markdown]
# <p>(pearson coefficient, p-value)</p>

# %% [markdown]
# <h2>ANOVA</h2>

# %%
f_oneway(iris['sepal-length'], iris['sepal-width'])
# Out:
# F_onewayResult(statistic=1335.7678308241748, pvalue=3.9878381148486907e-112)

# %% [markdown]
# <p>H0 is rejected</p>
